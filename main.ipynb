# %%
import pandas as pd

# %%
df = pd.read_csv('Lorong.csv', skiprows=5)
df.head(5)
# Out:
#                 Response ID                Timestamp Download Status  \
# 0  677627a5c5db5c49e3475f8c  02 Jan 2025 01:44:05 PM         Success
# 1  677b37d1572d5150400c570c  06 Jan 2025 09:54:25 AM         Success
# 2  677b7b926a64d3c12db444d8  06 Jan 2025 02:43:30 PM         Success
# 3  677b7f32b02186b36b22c28b  06 Jan 2025 02:58:58 PM         Success
# 4  677be9772ce1f94285a2325d  06 Jan 2025 10:32:23 PM         Success
#
#   Preferred Name                      Email  Mobile number  \
# 0           Chad       chad_goh@tech.gov.sg     6596267018
# 1  Tan Jun Xiang           junxiang@akro.ai     6581611147
# 2            Ian        ian@singpass.gov.sg     6584994902
# 3     Tan Fu Nan         tanfunan@gmail.com     6583660719
# 4       Khai Kit  wong_khai_kit@csit.gov.sg     6592342430
#
#   Can you share your LinkedIn profile URL? Can you share your GitHub profile?  \
# 0     https://www.linkedin.com/in/chadgoh/                                NaN
# ...

# %%
df2 = df[['Response ID', 'Timestamp', 'What is your current project focus?', 'Are there any needs or challenges you are facing that could benefit from community input?', 'What topics would you be interested in presenting?', 'Which areas of AI are you currently focusing on or have experience with?']]
df2.head(5)
# Out:
#                 Response ID                Timestamp  \
# 0  677627a5c5db5c49e3475f8c  02 Jan 2025 01:44:05 PM
# 1  677b37d1572d5150400c570c  06 Jan 2025 09:54:25 AM
# 2  677b7b926a64d3c12db444d8  06 Jan 2025 02:43:30 PM
# 3  677b7f32b02186b36b22c28b  06 Jan 2025 02:58:58 PM
# 4  677be9772ce1f94285a2325d  06 Jan 2025 10:32:23 PM
#
#                  What is your current project focus?  \
# 0  Figuring out a useful AI strategy for the product
# 1  Understanding knowledge management challenges ...
# 2                                           Singpass
# 3                     Improving chat bot performance
# 4  Getting/finding clean/high quality evaluation ...
#
#   Are there any needs or challenges you are facing that could benefit from community input?  \
# 0  Data aggregator that can potentially use AI to...
# 1  '- On-premise knowledge management system whic...
# 2                         Identifying Singpass Fraud
# 3       Applications of LLMs in career health space.
# ...

# %%
df2.to_csv('Lorong_cleaned.csv', index=False)
